# %% [markdown]
# <center>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/6/6f/Dauphine_logo_2019_-_Bleu.png" style="width: 600px;"/>
# </center>

# %% [markdown]
# <div align="center"><span style="font-family:Arial Black;font-size:33px;color:darkblue"> Master Economie Finance </span></div>

# %% [markdown]
# <div align="center"><span style="font-family:Arial Black;font-size:27px;color:darkblue">Application Lab – Risk measures</span></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Individual risk measures

# %% [markdown]
# ### Value at risk(VaR)

# %% [markdown]
# #### Historical Simulation

# %% [markdown]
# The VaR at the $\alpha\%$ level is the $\alpha\%$ quantile of the return distribution $(F)$:
#
# $$
# VaR_{t}(\alpha) = F^{-1}_{r_{t}}(\alpha)
# $$

# %%
#Data import
df_ret_asset = pd.read_csv('ret_asset.csv')
df_ret_asset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    753 non-null    object
#  1   ALL     753 non-null    float64
#  2   PNC     753 non-null    float64
#  3   MBI     753 non-null    float64
#  4   AIG     753 non-null    float64
#  5   HIG     753 non-null    float64
#  6   UNM     753 non-null    float64
#  7   HUM     753 non-null    float64
#  8   KEY     753 non-null    float64
#  9   CINF    753 non-null    float64
#  10  GS      753 non-null    float64
#  11  UNH     753 non-null    float64
#  12  BK      753 non-null    float64
#  13  NTRS    753 non-null    float64
#  14  PGR     753 non-null    float64
#  15  AXP     753 non-null    float64
#  16  SEIC    753 non-null    float64
#  17  FITB    753 non-null    float64
#  18  ZION    753 non-null    float64
#  19  CNA     753 non-null    float64
#  20  BEN     753 non-null    float64
# dtypes: float64(20), object(1)
# memory usage: 123.7+ KB

# %%
df_ret_asset['Date'] = pd.to_datetime(df_ret_asset['Date'])
df_ret_asset.set_index('Date', inplace = True)
df_ret_asset
# Out:
#                  ALL       PNC       MBI       AIG       HIG       UNM  \
# Date
# 2021-01-04 -1.697209  0.100616 -2.617549 -1.946986 -1.418752 -3.775711
# 2021-01-05 -0.789562 -0.531071  2.769412  1.656018 -0.664868  0.811548
# 2021-01-06  2.541334  5.347811  8.713781  6.313023  5.850093  6.392088
# 2021-01-07  0.072709  1.578433 -1.118892  1.676982 -0.908557 -0.931024
# 2021-01-08 -0.109084 -0.510734  3.591543 -0.662499 -1.017064 -0.768251
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  1.466302  0.460162  3.514164  0.539328  0.630360  0.378995
# 2023-12-26  0.493691  1.063392  3.326714  0.298370  0.288641  0.355398
# 2023-12-27  0.224254  0.582333 -8.605780  0.029795  0.212804  0.177231
# 2023-12-28  1.028015  0.405631 -0.327332  1.066521  0.561130  0.243176
# 2023-12-29  0.114359 -0.502448  0.327332 -0.176969 -0.049752 -0.154678
#
#                  HUM       KEY      CINF        GS       UNH        BK  \
# Date
# 2021-01-04  0.466896 -0.733942 -3.340047  0.487984 -0.337054 -1.783002
# 2021-01-05  0.239890  1.583458 -0.951259  2.213063 -1.353906  1.121064
# 2021-01-06  5.794736  9.283531  4.599857  5.255664  4.110966  6.541275
# 2021-01-07  2.227036  1.800867  0.045632  2.113733  1.590537  0.598076
# 2021-01-08 -2.469432 -1.361306  0.113984 -0.539773 -0.450286 -1.065728
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -0.163148  0.070005  0.000000  0.021015  0.082676  0.136094
# 2023-12-26 -0.081681  1.113441  0.684939  0.251880 -0.053822  0.966752
# 2023-12-27 -0.311855  0.483264  0.194834  0.749269  0.529325  0.192231
# 2023-12-28  1.117952  0.137643  0.620939  0.500719  0.402800  0.287663
# 2023-12-29  0.481710 -0.967529  0.067682 -0.165768  0.298648 -0.326081
#
#                 NTRS       PGR       AXP      SEIC      FITB       ZION  \
# Date
# 2021-01-04 -0.689509 -1.785671 -2.402294 -0.944065 -1.240892  -1.180975
# 2021-01-05 -0.748745 -0.185491  0.532296  0.455659  1.385876   1.571561
# 2021-01-06  5.797502  1.880104  3.632551  6.923768  9.164866  10.648343
# 2021-01-07  0.297635  0.555189 -0.791351  0.195597  3.825427   3.005309
# 2021-01-08 -0.709626 -0.253644  0.098583  0.649250 -0.830411  -2.573337
# ...              ...       ...       ...       ...       ...        ...
# 2023-12-22  0.047713  0.814668  0.421220  0.248018  0.203281   0.867390
# 2023-12-26  0.487839 -0.241156  0.209942 -0.015475  1.411511   1.980265
# 2023-12-27  0.379102  0.177754  0.589778  0.000001  0.314153  -0.827844
# 2023-12-28  0.460096  0.430376  0.394818 -0.312410  0.227854   0.336440
# 2023-12-29 -0.685017  0.591906 -0.245245 -0.580529 -0.894789  -1.784755
#
#                  CNA       BEN
# Date
# 2021-01-04 -2.442311 -2.635464
# 2021-01-05  0.603121 -0.246810
# 2021-01-06  5.369565  5.020126
# 2021-01-07 -0.223242 -0.156805
# 2021-01-08 -1.375192 -0.827261
# ...              ...       ...
# 2023-12-22  0.285916  0.506335
# 2023-12-26 -0.023791  1.271342
# 2023-12-27 -0.381497  0.331897
# 2023-12-28  0.974689 -0.398410
# 2023-12-29  0.094587 -0.902257
#
# [753 rows x 20 columns]

# %%
alpha = 0.05
df_ret_asset.quantile(alpha)
# Out:
# ALL    -2.249221
# PNC    -2.931314
# MBI    -4.829746
# AIG    -3.060443
# HIG    -2.394727
# UNM    -3.196311
# HUM    -2.482824
# KEY    -3.798497
# CINF   -2.450966
# GS     -2.472720
# UNH    -2.203455
# BK     -2.655114
# NTRS   -3.139406
# PGR    -2.205042
# AXP    -2.838759
# SEIC   -2.335234
# FITB   -3.450329
# ZION   -4.116127
# CNA    -2.321932
# BEN    -3.289422
# Name: 0.05, dtype: float64

# %% [markdown]
# #### Rolling window historical VaR

# %%
def rolling_var_historical(series, alpha=0.05, window=250):
    return series.rolling(window).quantile(alpha)

rolling_var = rolling_var_historical(df_ret_asset, alpha=0.05, window=250)
rolling_var
# Out:
#                  ALL       PNC       MBI      AIG       HIG       UNM  \
# Date
# 2021-01-04       NaN       NaN       NaN      NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN      NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN      NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN      NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN      NaN       NaN       NaN
# ...              ...       ...       ...      ...       ...       ...
# 2023-12-22 -2.503481 -2.932185 -3.988179 -2.62552 -2.112131 -2.470243
# 2023-12-26 -2.503481 -2.932185 -3.988179 -2.62552 -2.112131 -2.470243
# 2023-12-27 -2.503481 -2.932185 -4.007795 -2.62552 -2.112131 -2.470243
# 2023-12-28 -2.503481 -2.932185 -4.007795 -2.62552 -2.112131 -2.470243
# 2023-12-29 -2.503481 -2.932185 -4.007795 -2.62552 -2.112131 -2.470243
#
#                  HUM       KEY      CINF        GS       UNH        BK  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -2.778209 -4.855758 -2.226555 -2.271914 -1.886793 -2.131899
# 2023-12-26 -2.778209 -4.855758 -2.226555 -2.271914 -1.886793 -2.131899
# 2023-12-27 -2.778209 -4.855758 -2.226555 -2.271914 -1.886793 -2.131899
# 2023-12-28 -2.778209 -4.855758 -2.226555 -2.271914 -1.886793 -2.131899
# 2023-12-29 -2.778209 -4.855758 -2.226555 -2.271914 -1.886793 -2.131899
#
#                 NTRS       PGR      AXP      SEIC      FITB      ZION  \
# Date
# 2021-01-04       NaN       NaN      NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN      NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN      NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN      NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN      NaN       NaN       NaN       NaN
# ...              ...       ...      ...       ...       ...       ...
# 2023-12-22 -2.688562 -1.963234 -2.52052 -1.784228 -3.628244 -5.515923
# 2023-12-26 -2.688562 -1.963234 -2.52052 -1.784228 -3.628244 -5.515923
# 2023-12-27 -2.688562 -1.963234 -2.52052 -1.784228 -3.628244 -5.515923
# 2023-12-28 -2.688562 -1.963234 -2.52052 -1.784228 -3.628244 -5.515923
# 2023-12-29 -2.688562 -1.963234 -2.52052 -1.784228 -3.628244 -5.515923
#
#                  CNA       BEN
# Date
# 2021-01-04       NaN       NaN
# 2021-01-05       NaN       NaN
# 2021-01-06       NaN       NaN
# 2021-01-07       NaN       NaN
# 2021-01-08       NaN       NaN
# ...              ...       ...
# 2023-12-22 -2.101002 -2.806669
# 2023-12-26 -2.101002 -2.806669
# 2023-12-27 -2.101002 -2.779032
# 2023-12-28 -2.101002 -2.779032
# 2023-12-29 -2.101002 -2.779032
#
# [753 rows x 20 columns]

# %% [markdown]
# #### Predicted VaR

# %% [markdown]
# $$
# VaR^\alpha_{i, t+1 \mid t} = \sigma_{i, t+1 \mid t} \times q_{\alpha,t}
# $$
#
# where $\sigma_{i, t+1 \mid t}$ can be calculated based on Garch and $q_{\alpha,t} = F^{-1}_{\alpha} \left( { z_{i, t} } \right)$ is the conditional empirical $\alpha$-quantile of the standardized residuals $z_{i, t} = \frac{r_{i, t}}{\sigma_{i, t}}$.

# %%
from arch import arch_model

# %%
def compute_var(df_ret, window = 250, alpha = 0.05):

    # Create output DataFrames with same shape/index/columns
    df_Vol = pd.DataFrame(np.nan, index=df_ret.index, columns=df_ret.columns)
    df_Q05 = pd.DataFrame(np.nan, index=df_ret.index, columns=df_ret.columns)
    df_VaR = pd.DataFrame(np.nan, index=df_ret.index, columns=df_ret.columns)

    for col in df_ret.columns:
        col_idx = df_ret.columns.get_loc(col) + 1
        for j in range(window, len(df_ret[col])):
            
            # Slice the rolling window for the current asset.
            rolling_data = df_ret[col][j-window:j]

            # Fit GARCH(1,1) with Zero mean and normal distribution
            garch_model = arch_model(rolling_data, mean='Zero', vol='GARCH',p=1, q=1,dist='normal').fit(disp='off')

            # forecast(horizon=1).variance is σ^2，you MUST take the square root to get σ.
            sigma_forecast = np.sqrt(garch_model.forecast(horizon=1).variance.values[0, 0])

            # In-window conditional volatility σ_t and standardized residuals z_t
            sigma_in = garch_model.conditional_volatility.values  # σ_t for the window
            z = rolling_data / sigma_in  # equivalent to garch_model.std_resid

            # Empirical alpha-quantile within window
            q_alpha = np.quantile(z, alpha)

            # Save the results
            df_Vol.iloc[j, df_Vol.columns.get_loc(col)] = sigma_forecast
            df_Q05.iloc[j, df_Q05.columns.get_loc(col)] = q_alpha
            df_VaR.iloc[j, df_VaR.columns.get_loc(col)] = sigma_forecast * q_alpha

    return df_VaR, df_Vol, df_Q05

# %%
df_VaR_asset, df_Vol_asset, df_Q05 = compute_var(df_ret_asset)
# Out:
# /var/folders/l7/pj1hlfdd0ps42whw_xck619m0000gn/T/ipykernel_12087/2712206282.py:16: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   garch_model = arch_model(rolling_data, mean='Zero', vol='GARCH',p=1, q=1,dist='normal').fit(disp='off')
# /var/folders/l7/pj1hlfdd0ps42whw_xck619m0000gn/T/ipykernel_12087/2712206282.py:16: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   garch_model = arch_model(rolling_data, mean='Zero', vol='GARCH',p=1, q=1,dist='normal').fit(disp='off')
# Processing row 427/753, column 15/20
# Processing row 428/753, column 15/20
# Processing row 429/753, column 15/20
# Processing row 430/753, column 15/20
# Processing row 431/753, column 15/20
# Processing row 432/753, column 15/20
# Processing row 433/753, column 15/20
# Processing row 434/753, column 15/20
# Processing row 435/753, column 15/20
# Processing row 436/753, column 15/20
# Processing row 437/753, column 15/20
# Processing row 438/753, column 15/20
# Processing row 439/753, column 15/20
# Processing row 440/753, column 15/20
# Processing row 441/753, column 15/20
# Processing row 442/753, column 15/20
# Processing row 443/753, column 15/20
# Processing row 444/753, column 15/20
# Processing row 445/753, column 15/20
# Processing row 446/753, column 15/20
# Processing row 447/753, column 15/20
# Processing row 448/753, column 15/20
# Processing row 449/753, column 15/20
# Processing row 450/753, column 15/20
# Processing row 451/753, column 15/20
# Processing row 452/753, column 15/20
# Processing row 453/753, column 15/20
# Processing row 454/753, column 15/20
# Processing row 455/753, column 15/20
# Processing row 456/753, column 15/20
# Processing row 457/753, column 15/20
# Processing row 458/753, column 15/20
# Processing row 459/753, column 15/20
# Processing row 460/753, column 15/20
# Processing row 461/753, column 15/20
# Processing row 462/753, column 15/20
# Processing row 463/753, column 15/20
# Processing row 464/753, column 15/20
# Processing row 465/753, column 15/20
# Processing row 466/753, column 15/20
# Processing row 467/753, column 15/20
# Processing row 468/753, column 15/20
# Processing row 469/753, column 15/20
# Processing row 470/753, column 15/20
# Processing row 471/753, column 15/20
# Processing row 472/753, column 15/20
# Processing row 473/753, column 15/20
# Processing row 474/753, column 15/20
# Processing row 475/753, column 15/20
# Processing row 476/753, column 15/20
# Processing row 477/753, column 15/20
# Processing row 478/753, column 15/20
# Processing row 479/753, column 15/20
# Processing row 480/753, column 15/20
# Processing row 481/753, column 15/20
# Processing row 482/753, column 15/20
# Processing row 483/753, column 15/20
# Processing row 484/753, column 15/20
# Processing row 485/753, column 15/20
# Processing row 486/753, column 15/20
# Processing row 487/753, column 15/20
# Processing row 488/753, column 15/20
# Processing row 489/753, column 15/20
# Processing row 490/753, column 15/20
# Processing row 491/753, column 15/20
# Processing row 492/753, column 15/20
# Processing row 493/753, column 15/20
# Processing row 494/753, column 15/20
# Processing row 495/753, column 15/20
# Processing row 496/753, column 15/20
# Processing row 497/753, column 15/20
# Processing row 498/753, column 15/20
# Processing row 499/753, column 15/20
# Processing row 500/753, column 15/20
# Processing row 501/753, column 15/20
# Processing row 502/753, column 15/20
# Processing row 503/753, column 15/20
# Processing row 504/753, column 15/20
# Processing row 505/753, column 15/20
# Processing row 506/753, column 15/20
# Processing row 507/753, column 15/20
# Processing row 508/753, column 15/20
# Processing row 509/753, column 15/20
# Processing row 510/753, column 15/20
# Processing row 511/753, column 15/20
# Processing row 512/753, column 15/20
# Processing row 513/753, column 15/20
# Processing row 514/753, column 15/20
# Processing row 515/753, column 15/20
# Processing row 516/753, column 15/20
# Processing row 517/753, column 15/20
# Processing row 518/753, column 15/20
# Processing row 519/753, column 15/20
# Processing row 520/753, column 15/20
# Processing row 521/753, column 15/20
# Processing row 522/753, column 15/20
# Processing row 523/753, column 15/20
# Processing row 524/753, column 15/20
# Processing row 525/753, column 15/20
# Processing row 526/753, column 15/20
# Processing row 527/753, column 15/20
# Processing row 528/753, column 15/20
# Processing row 529/753, column 15/20
# Processing row 530/753, column 15/20
# Processing row 531/753, column 15/20
# Processing row 532/753, column 15/20
# Processing row 533/753, column 15/20
# Processing row 534/753, column 15/20
# Processing row 535/753, column 15/20
# Processing row 536/753, column 15/20
# Processing row 537/753, column 15/20
# Processing row 538/753, column 15/20
# Processing row 539/753, column 15/20
# Processing row 540/753, column 15/20
# Processing row 541/753, column 15/20
# Processing row 542/753, column 15/20
# Processing row 543/753, column 15/20
# Processing row 544/753, column 15/20
# Processing row 545/753, column 15/20
# Processing row 546/753, column 15/20
# Processing row 547/753, column 15/20
# Processing row 548/753, column 15/20
# Processing row 549/753, column 15/20
# Processing row 550/753, column 15/20
# Processing row 551/753, column 15/20
# Processing row 552/753, column 15/20
# Processing row 553/753, column 15/20
# Processing row 554/753, column 15/20
# Processing row 555/753, column 15/20
# Processing row 556/753, column 15/20
# Processing row 557/753, column 15/20
# Processing row 558/753, column 15/20
# Processing row 559/753, column 15/20
# Processing row 560/753, column 15/20
# Processing row 561/753, column 15/20
# Processing row 562/753, column 15/20
# Processing row 563/753, column 15/20
# Processing row 564/753, column 15/20
# Processing row 565/753, column 15/20
# Processing row 566/753, column 15/20
# Processing row 567/753, column 15/20
# Processing row 568/753, column 15/20
# Processing row 569/753, column 15/20
# Processing row 570/753, column 15/20
# Processing row 571/753, column 15/20
# Processing row 572/753, column 15/20
# Processing row 573/753, column 15/20
# Processing row 574/753, column 15/20
# Processing row 575/753, column 15/20
# Processing row 576/753, column 15/20
# Processing row 577/753, column 15/20
# Processing row 578/753, column 15/20
# Processing row 579/753, column 15/20
# Processing row 580/753, column 15/20
# Processing row 581/753, column 15/20
# Processing row 582/753, column 15/20
# Processing row 583/753, column 15/20
# Processing row 584/753, column 15/20
# Processing row 585/753, column 15/20
# Processing row 586/753, column 15/20
# Processing row 587/753, column 15/20
# Processing row 588/753, column 15/20
# Processing row 589/753, column 15/20
# Processing row 590/753, column 15/20
# Processing row 591/753, column 15/20
# Processing row 592/753, column 15/20
# Processing row 593/753, column 15/20
# Processing row 594/753, column 15/20
# Processing row 595/753, column 15/20
# Processing row 596/753, column 15/20
# Processing row 597/753, column 15/20
# Processing row 598/753, column 15/20
# Processing row 599/753, column 15/20
# Processing row 600/753, column 15/20
# Processing row 601/753, column 15/20
# Processing row 602/753, column 15/20
# Processing row 603/753, column 15/20
# Processing row 604/753, column 15/20
# Processing row 605/753, column 15/20
# Processing row 606/753, column 15/20
# Processing row 607/753, column 15/20
# Processing row 608/753, column 15/20
# Processing row 609/753, column 15/20
# Processing row 610/753, column 15/20
# Processing row 611/753, column 15/20
# Processing row 612/753, column 15/20
# Processing row 613/753, column 15/20
# Processing row 614/753, column 15/20
# Processing row 615/753, column 15/20
# Processing row 616/753, column 15/20
# Processing row 617/753, column 15/20
# Processing row 618/753, column 15/20
# Processing row 619/753, column 15/20
# Processing row 620/753, column 15/20
# Processing row 621/753, column 15/20
# Processing row 622/753, column 15/20
# Processing row 623/753, column 15/20
# Processing row 624/753, column 15/20
# Processing row 625/753, column 15/20
# Processing row 626/753, column 15/20
# Processing row 627/753, column 15/20
# Processing row 628/753, column 15/20
# Processing row 629/753, column 15/20
# Processing row 630/753, column 15/20
# Processing row 631/753, column 15/20
# Processing row 632/753, column 15/20
# Processing row 633/753, column 15/20
# Processing row 634/753, column 15/20
# Processing row 635/753, column 15/20
# Processing row 636/753, column 15/20
# Processing row 637/753, column 15/20
# Processing row 638/753, column 15/20
# Processing row 639/753, column 15/20
# Processing row 640/753, column 15/20
# Processing row 641/753, column 15/20
# Processing row 642/753, column 15/20
# Processing row 643/753, column 15/20
# Processing row 644/753, column 15/20
# Processing row 645/753, column 15/20
# Processing row 646/753, column 15/20
# Processing row 647/753, column 15/20
# Processing row 648/753, column 15/20
# Processing row 649/753, column 15/20
# Processing row 650/753, column 15/20
# Processing row 651/753, column 15/20
# Processing row 652/753, column 15/20
# Processing row 653/753, column 15/20
# Processing row 654/753, column 15/20
# Processing row 655/753, column 15/20
# Processing row 656/753, column 15/20
# Processing row 657/753, column 15/20
# Processing row 658/753, column 15/20
# Processing row 659/753, column 15/20
# Processing row 660/753, column 15/20
# Processing row 661/753, column 15/20
# Processing row 662/753, column 15/20
# Processing row 663/753, column 15/20
# Processing row 664/753, column 15/20
# Processing row 665/753, column 15/20
# Processing row 666/753, column 15/20
# Processing row 667/753, column 15/20
# Processing row 668/753, column 15/20
# Processing row 669/753, column 15/20
# Processing row 670/753, column 15/20
# Processing row 671/753, column 15/20
# Processing row 672/753, column 15/20
# Processing row 673/753, column 15/20
# Processing row 674/753, column 15/20
# Processing row 675/753, column 15/20
# Processing row 676/753, column 15/20
# Processing row 677/753, column 15/20
# Processing row 678/753, column 15/20
# Processing row 679/753, column 15/20
# Processing row 680/753, column 15/20
# Processing row 681/753, column 15/20
# Processing row 682/753, column 15/20
# Processing row 683/753, column 15/20
# Processing row 684/753, column 15/20
# Processing row 685/753, column 15/20
# Processing row 686/753, column 15/20
# Processing row 687/753, column 15/20
# Processing row 688/753, column 15/20
# Processing row 689/753, column 15/20
# Processing row 690/753, column 15/20
# Processing row 691/753, column 15/20
# Processing row 692/753, column 15/20
# Processing row 693/753, column 15/20
# Processing row 694/753, column 15/20
# Processing row 695/753, column 15/20
# Processing row 696/753, column 15/20
# Processing row 697/753, column 15/20
# Processing row 698/753, column 15/20
# Processing row 699/753, column 15/20
# Processing row 700/753, column 15/20
# Processing row 701/753, column 15/20
# Processing row 702/753, column 15/20
# Processing row 703/753, column 15/20
# Processing row 704/753, column 15/20
# Processing row 705/753, column 15/20
# Processing row 706/753, column 15/20
# Processing row 707/753, column 15/20
# Processing row 708/753, column 15/20
# Processing row 709/753, column 15/20
# Processing row 710/753, column 15/20
# Processing row 711/753, column 15/20
# Processing row 712/753, column 15/20
# Processing row 713/753, column 15/20
# Processing row 714/753, column 15/20
# Processing row 715/753, column 15/20
# Processing row 716/753, column 15/20
# Processing row 717/753, column 15/20
# Processing row 718/753, column 15/20
# Processing row 719/753, column 15/20
# Processing row 720/753, column 15/20
# Processing row 721/753, column 15/20
# Processing row 722/753, column 15/20
# Processing row 723/753, column 15/20
# Processing row 724/753, column 15/20
# Processing row 725/753, column 15/20
# Processing row 726/753, column 15/20
# Processing row 727/753, column 15/20
# Processing row 728/753, column 15/20
# Processing row 729/753, column 15/20
# Processing row 730/753, column 15/20
# Processing row 731/753, column 15/20
# Processing row 732/753, column 15/20
# Processing row 733/753, column 15/20
# Processing row 734/753, column 15/20
# Processing row 735/753, column 15/20
# Processing row 736/753, column 15/20
# Processing row 737/753, column 15/20
# Processing row 738/753, column 15/20
# Processing row 739/753, column 15/20
# Processing row 740/753, column 15/20
# Processing row 741/753, column 15/20
# Processing row 742/753, column 15/20
# Processing row 743/753, column 15/20
# Processing row 744/753, column 15/20
# Processing row 745/753, column 15/20
# Processing row 746/753, column 15/20
# Processing row 747/753, column 15/20
# Processing row 748/753, column 15/20
# Processing row 749/753, column 15/20
# Processing row 750/753, column 15/20
# Processing row 751/753, column 15/20
# Processing row 752/753, column 15/20
# Processing row 753/753, column 15/20
# Processing row 251/753, column 16/20
# Processing row 252/753, column 16/20
# Processing row 253/753, column 16/20
# Processing row 254/753, column 16/20
# Processing row 255/753, column 16/20
# Processing row 256/753, column 16/20
# Processing row 257/753, column 16/20
# Processing row 258/753, column 16/20
# Processing row 259/753, column 16/20
# Processing row 260/753, column 16/20
# Processing row 261/753, column 16/20
# Processing row 262/753, column 16/20
# Processing row 263/753, column 16/20
# Processing row 264/753, column 16/20
# Processing row 265/753, column 16/20
# Processing row 266/753, column 16/20
# Processing row 267/753, column 16/20
# Processing row 268/753, column 16/20
# Processing row 269/753, column 16/20
# Processing row 270/753, column 16/20
# Processing row 271/753, column 16/20
# Processing row 272/753, column 16/20
# Processing row 273/753, column 16/20
# Processing row 274/753, column 16/20
# Processing row 275/753, column 16/20
# Processing row 276/753, column 16/20
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  0.047713  0.814668  0.421220  0.248018  0.203281  0.867390
# 2023-12-26  0.487839 -0.241156  0.209942 -0.015475  1.411511  1.980265
# 2023-12-27  0.379102  0.177754  0.589778  0.000001  0.314153 -0.827844
# 2023-12-28  0.460096  0.430376  0.394818 -0.312410  0.227854  0.336440
# 2023-12-29 -0.685017  0.591906 -0.245245 -0.580529 -0.894789 -1.784755
#
#                  CNA       BEN
# Date
# 2021-12-30 -1.059884 -0.355135
# 2021-12-31 -0.068032  0.149419
# 2022-01-03  1.374353 -0.239169
# 2022-01-04  2.191084  2.395505
# 2022-01-05 -1.233499 -1.057591
# ...              ...       ...
# 2023-12-22  0.285916  0.506335
# 2023-12-26 -0.023791  1.271342
# 2023-12-27 -0.381497  0.331897
# 2023-12-28  0.974689 -0.398410
# 2023-12-29  0.094587 -0.902257
#
# [503 rows x 20 columns]

# %%
from scipy.stats import chi2

# %% [markdown]
# ### Unconditional coverage test

# %% [markdown]
# Kupiec (1995) introduced a variation on the binomial test called the proportion of failures (POF) test.
# The POF test works with the binomial distribution approach. In addition, it uses a likelihood ratio to test whether the probability of exceptions is synchronized with the probability \(p\) implied by the VaR confidence level.
# If the data suggests that the probability of exceptions is different than \(p\), the VaR model is rejected.
#
# The POF test statistic is
#
# $$
# LR_{POF} = -2 \log \left( \frac{(1-p)^{N-x} p^x}{\left(1-\frac{x}{N}\right)^{N-x} \left(\frac{x}{N}\right)^x} \right)
# $$
#
# where \(x\) is the number of failures, \(N\) the number of observations and \(p = VaR level\).
#
# This statistic is asymptotically distributed as a chi-square variable with 1 degree of freedom.
# The VaR model fails the test if this likelihood ratio exceeds a critical value.
# The critical value depends on the test confidence level.

# %% [markdown]
# ### Independence test

# %% [markdown]
# Christoffersen (1998) proposed a test to measure whether the probability of observing an exception on a particular day depends on whether an exception occurred.
# Unlike the unconditional probability of observing an exception, Christoffersen's test measures the dependency between consecutive days only.
# The test statistic for independence in Christoffersen’s interval forecast (IF) approach is given by:
#
# $$
# LR_{CCI} = -2 \log \left(
# \frac{(1 - \pi)^{n00+n10} \pi^{n01+n11}}
# {(1 - \pi_0)^{n00} \pi_0^{n01} (1 - \pi_1)^{n10} \pi_1^{n11}}
# \right)
# $$
#
# where
#
# - \(n00\) = Number of periods with no failures followed by a period with no failures.
# - \(n10\) = Number of periods with failures followed by a period with no failures.
# - \(n01\) = Number of periods with no failures followed by a period with failures.
# - \(n11\) = Number of periods with failures followed by a period with failures.
#
# and
#
# - $\pi_0$ — Probability of having a failure on period \(t\), given that no failure occurred on period \(t-1\):
# $$
#   \pi_0 = \frac{n01}{n00 + n01}
# $$
#
# - $\pi_1$ — Probability of having a failure on period \(t\), given that a failure occurred on period \(t-1\):
#   $$
#   \pi_1 = \frac{n11}{n10 + n11}
#   $$
#
# - $\pi$ — Probability of having a failure on period \(t\):
#   $$
#   \pi = \frac{n01 + n11}{n00 + n01 + n10 + n11}
#   $$
#
#
# This statistic is asymptotically distributed as a chi-square variable with 1 degree of freedom.

# %% [markdown]
# ### CC test

# %% [markdown]
# Christoffersen (1998) also proposed the **Conditional Coverage (CC) test**, which jointly evaluates whether the frequency of exceptions is correct (Unconditional Coverage, UC) **and** whether exceptions occur independently (Independence, IND).
#
# The test statistic is simply the sum of the UC and IND likelihood ratio statistics:
#
# $$
# LR_{CC} = LR_{UC} + LR_{CCI}
# $$
#
#
# This statistic is asymptotically distributed as a chi-square variable with 2 degrees of freedom.

# %%
def coverage_test_log_05(df_returns, df_VaR, alpha=0.05, test_alpha=0.05):
    results_list = []
    eps = 1e-12  # small epsilon to avoid log(0) / division by zero

    for col_name in df_VaR.columns:
        print(f"\nResults of {col_name}:")
        # Merge/align returns and VaR on the same date index.
        df_test = pd.merge(pd.DataFrame(df_returns[col_name]).reset_index(),pd.DataFrame(df_VaR[col_name].dropna()).reset_index(),
            on="Date", how="inner").set_index("Date")
        # Extract the aligned return series and VaR series
        returns = df_test.iloc[:, 0].astype(float)
        var_series = df_test.iloc[:, 1].astype(float)

        #  Build the Exception indicator I_t = 1{ r_t < VaR_t } and drop NaN.
        I = (returns < var_series).astype(int)
        I = I.dropna()
        T = len(I)

        # ---------- UC (Kupiec) ----------
        # Count violations and non-violations
        n_1 = int(I.sum())
        n_0 = T - n_1
        pi_hat_uc = n_1 / T 

        # Guard against log(0) by clipping probabilities with eps.
        a0 = max(1 - alpha, eps)
        a1 = max(alpha, eps)
        p0 = max(1 - pi_hat_uc, eps)
        p1 = max(pi_hat_uc, eps)
        # UC likelihoods
        log_L_uc_H0 = n_0 * np.log(a0) + n_1 * np.log(a1)
        log_L_uc_H1 = n_0 * np.log(p0) + n_1 * np.log(p1)
        # UC LR stat and p-value
        LR_uc = -2 * (log_L_uc_H0 - log_L_uc_H1)
        Pvalue_uc = 1 - chi2.cdf(LR_uc, 1)

        # ---------- Ind (Christoffersen independence) ----------
        # Build lag/lead of I_t to count transitions n_00, n_01, n_10, n_11
        I_lag = I.iloc[:-1].values
        I_lead = I.iloc[1:].values
        n_00 = int(((I_lag == 0) & (I_lead == 0)).sum())
        n_01 = int(((I_lag == 0) & (I_lead == 1)).sum())
        n_10 = int(((I_lag == 1) & (I_lead == 0)).sum())
        n_11 = int(((I_lag == 1) & (I_lead == 1)).sum())
        
        # Denominators and totals for transition probabilities.
        denom0 = n_00 + n_01
        denom1 = n_10 + n_11
        total  = n_00 + n_01 + n_10 + n_11

        # H0 overall failure prob and H1 transition probs
        pi_hat_ind = (n_01 + n_11) / total 
        pi_hat_01 = n_01 / denom0 
        pi_hat_11 = n_11 / denom1 

        # Guard logs for Ind part
        q0 = max(1 - pi_hat_ind, eps)
        q1 = max(pi_hat_ind, eps)
        r00 = max(1 - pi_hat_01, eps)
        r01 = max(pi_hat_01, eps)
        r10 = max(1 - pi_hat_11, eps)
        r11 = max(pi_hat_11, eps)
        # Ind likelihoods
        log_L_ind_H0 = (n_00 + n_10) * np.log(q0) + (n_01 + n_11) * np.log(q1)
        log_L_ind_H1 = n_00 * np.log(r00) + n_01 * np.log(r01) + n_10 * np.log(r10) + n_11 * np.log(r11)
        # Ind LR stat and p-value
        LR_ind = -2 * (log_L_ind_H0 - log_L_ind_H1)
        Pvalue_ind = 1 - chi2.cdf(LR_ind, 1)

        # ---------- CC (Christoffersen conditional coverage) ----------
        
        LR_cc = LR_uc + LR_ind
        Pvalue_cc = 1 - chi2.cdf(LR_cc, 2)

        print(f"UC test:  LR = {LR_uc:.4f}, p-value = {Pvalue_uc:.4f}")
        print(f"Ind test: LR = {LR_ind:.4f}, p-value = {Pvalue_ind:.4f}")
        print(f"CC test:  LR = {LR_cc:.4f}, p-value = {Pvalue_cc:.4f}")

        results_list.append([col_name, Pvalue_uc, Pvalue_ind, Pvalue_cc])

    df_results = pd.DataFrame(results_list, columns=["Company", "UC p-value", "Ind p-value", "CC p-value"])

    df_summary = pd.DataFrame({
        f"p < {test_alpha}": [
            np.sum(df_results["UC p-value"]  < test_alpha),
            np.sum(df_results["Ind p-value"] < test_alpha),
            np.sum(df_results["CC p-value"]  < test_alpha)
        ],
        f"p ≥ {test_alpha}": [
            np.sum(df_results["UC p-value"]  >= test_alpha),
            np.sum(df_results["Ind p-value"] >= test_alpha),
            np.sum(df_results["CC p-value"]  >= test_alpha)
        ],
        "NaN": [
            np.sum(df_results["UC p-value"].isna()),
            np.sum(df_results["Ind p-value"].isna()),
            np.sum(df_results["CC p-value"].isna())
        ]
    }, index=["UC", "Ind", "CC"])

    df_reject = pd.DataFrame({
        f"Reject (<{test_alpha})": [
            df_results.loc[df_results["UC p-value"]  < test_alpha, "Company"].tolist(),
            df_results.loc[df_results["Ind p-value"] < test_alpha, "Company"].tolist(),
            df_results.loc[df_results["CC p-value"]  < test_alpha, "Company"].tolist()
        ]
    }, index=["UC", "Ind", "CC"])

    return df_results, df_summary, df_reject

# %%
df_results_05, df_summary_05, df_reject_05 = coverage_test_log_05(df_ret_asset_bt, df_VaR_asset_bt, alpha=0.05, test_alpha = 0.05)
print(df_summary_05)
print(df_reject_05)
# Out:
# Results of ALL:
# UC test:  LR = 0.3284, p-value = 0.5666
# Ind test: LR = 0.1279, p-value = 0.7206
# CC test:  LR = 0.4563, p-value = 0.7960
#
# Results of PNC:
# UC test:  LR = 0.9298, p-value = 0.3349
# Ind test: LR = 0.4636, p-value = 0.4959
# CC test:  LR = 1.3934, p-value = 0.4982
#
# Results of MBI:
# UC test:  LR = 0.9298, p-value = 0.3349
# Ind test: LR = 0.4636, p-value = 0.4959
# CC test:  LR = 1.3934, p-value = 0.4982
#
# Results of AIG:
# UC test:  LR = 1.3379, p-value = 0.2474
# Ind test: LR = 2.0404, p-value = 0.1532
# CC test:  LR = 3.3783, p-value = 0.1847
#
# Results of HIG:
# UC test:  LR = 0.9298, p-value = 0.3349
# Ind test: LR = 0.7827, p-value = 0.3763
# CC test:  LR = 1.7124, p-value = 0.4248
#
# Results of UNM:
# UC test:  LR = 2.3650, p-value = 0.1241
# Ind test: LR = 9.2977, p-value = 0.0023
# CC test:  LR = 11.6626, p-value = 0.0029
#
# Results of HUM:
# UC test:  LR = 2.3585, p-value = 0.1246
# Ind test: LR = 0.0155, p-value = 0.9009
# CC test:  LR = 2.3740, p-value = 0.3051
#
# Results of KEY:
# UC test:  LR = 0.1400, p-value = 0.7082
# Ind test: LR = 0.2090, p-value = 0.6475
# CC test:  LR = 0.3490, p-value = 0.8399
#
# Results of CINF:
# UC test:  LR = 0.1989, p-value = 0.6556
# Ind test: LR = 0.0031, p-value = 0.9559
# CC test:  LR = 0.2020, p-value = 0.9039
#
# Results of GS:
# UC test:  LR = 0.0562, p-value = 0.8127
# Ind test: LR = 2.3778, p-value = 0.1231
# CC test:  LR = 2.4340, p-value = 0.2961
#
# Results of UNH:
# UC test:  LR = 0.0009, p-value = 0.9755
# Ind test: LR = 4.5092, p-value = 0.0337
# CC test:  LR = 4.5101, p-value = 0.1049
#
# Results of BK:
# UC test:  LR = 0.4328, p-value = 0.5106
# Ind test: LR = 2.0174, p-value = 0.1555
# CC test:  LR = 2.4502, p-value = 0.2937
#
# Results of NTRS:
# UC test:  LR = 0.0299, p-value = 0.8627
# Ind test: LR = 1.7323, p-value = 0.1881
# CC test:  LR = 1.7622, p-value = 0.4143
#
# Results of PGR:
# UC test:  LR = 0.4328, p-value = 0.5106
# Ind test: LR = 0.0014, p-value = 0.9697
# CC test:  LR = 0.4343, p-value = 0.8048
#
# Results of AXP:
# UC test:  LR = 0.0009, p-value = 0.9755
# Ind test: LR = 2.0395, p-value = 0.1533
# CC test:  LR = 2.0405, p-value = 0.3605
#
# Results of SEIC:
# UC test:  LR = 0.0299, p-value = 0.8627
# Ind test: LR = 0.3113, p-value = 0.5769
# CC test:  LR = 0.3413, p-value = 0.8431
#
# Results of FITB:
# UC test:  LR = 0.0299, p-value = 0.8627
# Ind test: LR = 0.3113, p-value = 0.5769
# CC test:  LR = 0.3413, p-value = 0.8431
#
# Results of ZION:
# UC test:  LR = 0.5925, p-value = 0.4415
# Ind test: LR = 0.3527, p-value = 0.5526
# CC test:  LR = 0.9452, p-value = 0.6234
#
# Results of CNA:
# UC test:  LR = 0.0562, p-value = 0.8127
# Ind test: LR = 2.3778, p-value = 0.1231
# CC test:  LR = 2.4340, p-value = 0.2961
#
# Results of BEN:
# UC test:  LR = 2.3650, p-value = 0.1241
# Ind test: LR = 0.1814, p-value = 0.6702
# CC test:  LR = 2.5464, p-value = 0.2799
#      p < 0.05  p ≥ 0.05  NaN
# UC          0        20    0
# Ind         2        18    0
# CC          1        19    0
#     Reject (<0.05)
# UC              []
# Ind     [UNM, UNH]
# CC           [UNM]

# %% [markdown]
# ## CoVaR (Adrian and Brunnermeier, 2014)
#
# The **CoVaR** is the Value-at-Risk of the market return given a specific event on the firm return:
#
# $$
# \Pr\left( r_{mt} \leq CoVaR_{t}^{m \mid r_{it} = VaR_{it}(\alpha)} \ \big|\ r_{it} = VaR_{it}(\alpha) \right) = \alpha.
# $$
#
#
# ## ΔCoVaR
#
# The contribution of the institution to systemic risk, **ΔCoVaR**, is the difference between its CoVaR and the CoVaR calculated at the median state:
#
# $$
# \Delta CoVaR_{it}(\alpha) = CoVaR_{t}^{m \mid r_{it} = VaR_{it}(\alpha)} - CoVaR_{t}^{m \mid r_{it} = Median(r_{it})}.
# $$
#
# ---
#
#
#
# Under the **Gaussian linear assumption**, the ΔCoVaR can be written as:
#
# $$
# \Delta CoVaR_{\alpha}^{m \mid i,t+1}
# = \rho_{m,i,t+1} \times \frac{\sigma_{m,t+1}}{\sigma_{i,t+1}} \times
# \Big( VaR_{\alpha}^{i,t+1} - \text{Median}(r_{i,t}) \Big).
# $$

# %%
# Market return
df_ret_mkt = pd.read_csv('ret_mkt.csv')
df_ret_mkt['Date'] = pd.to_datetime(df_ret_mkt['Date'])
df_ret_mkt.set_index('Date', inplace = True)
df_ret_mkt
# Out:
#             Return_mkt
# Date
# 2021-01-04   -1.292168
# 2021-01-05    0.255675
# 2021-01-06    4.277497
# 2021-01-07    1.673655
# 2021-01-08   -0.141270
# ...                ...
# 2023-12-22    0.262737
# 2023-12-26    0.433775
# 2023-12-27    0.283583
# 2023-12-28    0.356060
# 2023-12-29   -0.205864
#
# [753 rows x 1 columns]

# %%
# Calculate the market predicted volatility using function compute_var()
df_VaR_mkt, df_Vol_mkt, df_Q05_mkt = compute_var(df_ret_mkt)

# %%
df_Vol_mkt
# Out:
#             Return_mkt
# Date
# 2021-01-04         NaN
# 2021-01-05         NaN
# 2021-01-06         NaN
# 2021-01-07         NaN
# 2021-01-08         NaN
# ...                ...
# 2023-12-22    1.000242
# 2023-12-26    0.915506
# 2023-12-27    0.869101
# 2023-12-28    0.827267
# 2023-12-29    0.802914
#
# [753 rows x 1 columns]

# %% [markdown]
# # ρ in DCC(1,1): Engle (2002) Dynamic Conditional Correlation
#
# ## 1) Covariance–correlation decomposition
# Let $H_t$ be the $N\times N$ **conditional covariance** matrix of returns $\varepsilon_t$ (innovations):
# $$
# H_t = D_t\, R_t\, D_t,
# $$
# where $D_t=\mathrm{diag}\big(\sqrt{h_{1t}},\ldots,\sqrt{h_{Nt}}\big)$ collects **univariate conditional volatilities** (from any GARCH for each series), and $R_t$ is the **time-varying correlation matrix**.
#
# ---
#
# ## 2) Standardized residuals
# Define standardized residuals
# $$
# u_t = D_t^{-1}\varepsilon_t = \big(u_{1t},\ldots,u_{Nt}\big)^\top,
# \qquad u_{it}=\frac{\varepsilon_{it}}{\sqrt{h_{it}}}.
# $$
#
# Let $\bar Q=\mathbb{E}[u_tu_t^\top]$ denote the **unconditional covariance** of $u_t$ (in practice, the sample covariance/correlation of standardized residuals) and assume $\bar Q$ is positive definite.
#
# ---
#
# ## 3) DCC(1,1) dynamics (Engle, 2002)
# Introduce an auxiliary $N\times N$ symmetric positive definite matrix $Q_t$ that follows a GARCH-type recursion:
# $$
# \boxed{\quad
# Q_t=(1-\alpha-\beta)\,\bar Q\;+\;\alpha\,u_{t-1}u_{t-1}^\top\;+\;\beta\,Q_{t-1},
# \quad \alpha\ge 0,\;\beta\ge 0,\;\alpha+\beta<1.
# \quad}
# $$
#
# The **dynamic correlation matrix** is then obtained by scaling $Q_t$ to unit diagonal:
# $$
# \boxed{\quad
# R_t = \mathrm{diag}(Q_t)^{-1/2}\; Q_t\; \mathrm{diag}(Q_t)^{-1/2}.
# \quad}
# $$
#
# ---
#
# ## 4) Pairwise correlation coefficient $ \rho_{ij,t} $
# Let $q_{ij,t}$ denote the $(i,j)$ element of $Q_t$.
# Then the DCC correlation between series $i$ and $j$ is
# $$
# \boxed{\quad
# \rho_{ij,t}=\frac{q_{ij,t}}{\sqrt{q_{ii,t}\,q_{jj,t}}}.
# \quad}
# $$
#
# ---
#
# ## 5) Bivariate explicit formula
# For $N=2$, write $\bar Q=\begin{pmatrix}\bar q_{11}&\bar q_{12}\\ \bar q_{12}&\bar q_{22}\end{pmatrix}$.
# The recursion for each element is
# $$
# \begin{aligned}
# q_{12,t} &= (1-\alpha-\beta)\,\bar q_{12} + \alpha\,u_{1,t-1}u_{2,t-1} + \beta\,q_{12,t-1},\\[2pt]
# q_{11,t} &= (1-\alpha-\beta)\,\bar q_{11} + \alpha\,u_{1,t-1}^2       + \beta\,q_{11,t-1},\\[2pt]
# q_{22,t} &= (1-\alpha-\beta)\,\bar q_{22} + \alpha\,u_{2,t-1}^2       + \beta\,q_{22,t-1}.
# \end{aligned}
# $$
# Hence the DCC(1,1) correlation is
# $$
# \boxed{\quad
# \rho_{12,t}
# =\frac{(1-\alpha-\beta)\,\bar q_{12}+\alpha\,u_{1,t-1}u_{2,t-1}+\beta\,q_{12,t-1}}
# {\sqrt{\Big((1-\alpha-\beta)\,\bar q_{11}+\alpha\,u_{1,t-1}^2+\beta\,q_{11,t-1}\Big)
#       \Big((1-\alpha-\beta)\,\bar q_{22}+\alpha\,u_{2,t-1}^2+\beta\,q_{22,t-1}\Big)}}.
# \quad}
# $$

# %% [markdown]
# The multivariate GARCH (MGARCH) in python is not well developped, so let's move to R just for illustration

# %%
df_Rho = pd.read_csv('DCC_Rho.csv')
df_Rho['Date'] = pd.to_datetime(df_Rho['Date'])
df_Rho.set_index('Date', inplace = True)
df_Rho
# Out:
#                  ALL       PNC       MBI       AIG       HIG       UNM  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  0.475766  0.846767  0.156748  0.684265  0.660077  0.393421
# 2023-12-26  0.481583  0.788644       NaN  0.690073  0.660041  0.406576
# 2023-12-27  0.490606  0.782244  0.161043  0.695064  0.660478  0.422486
# 2023-12-28  0.496635  0.775076  0.140085  0.693198  0.660045  0.428529
# 2023-12-29  0.505348  0.767424  0.124815  0.693965  0.659911  0.435582
#
#                  HUM       KEY      CINF        GS       UNH        BK  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  0.245267  0.706959  0.576749  0.717409  0.344079  0.801277
# 2023-12-26  0.244916  0.706761  0.575746  0.716216  0.343258  0.764090
# 2023-12-27  0.244987  0.711873  0.575457  0.715320  0.343200  0.764423
# 2023-12-28  0.245380  0.710187  0.574456  0.716248  0.343084  0.746843
# 2023-12-29  0.247109  0.705715  0.572981  0.716728  0.343374  0.741842
#
#                 NTRS       PGR       AXP      SEIC      FITB      ZION  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  0.834009  0.354048  0.780077  0.717005  0.777542  0.711914
# 2023-12-26  0.808932  0.341799  0.757391  0.721823  0.777897  0.710428
# 2023-12-27  0.791080  0.296407  0.732103  0.710866  0.778555  0.712069
# 2023-12-28  0.774538  0.324018  0.723146  0.713256  0.778565  0.700310
# 2023-12-29  0.759387  0.335436  0.712266  0.692762  0.778231  0.700767
#
#                  CNA       BEN
# Date
# 2021-01-04       NaN       NaN
# 2021-01-05       NaN       NaN
# 2021-01-06       NaN       NaN
# 2021-01-07       NaN       NaN
# 2021-01-08       NaN       NaN
# ...              ...       ...
# 2023-12-22  0.335541  0.696977
# 2023-12-26  0.364455  0.692642
# 2023-12-27  0.379961  0.694516
# 2023-12-28  0.378866  0.703250
# 2023-12-29  0.422582  0.664711
#
# [753 rows x 20 columns]

# %%
# Now calculate the Delta CoVaR as in the equation
df_DCoVaR = pd.DataFrame(index=df_Rho.index, columns=df_Rho.columns)
for column in df_Rho.columns:
    combined_df = pd.concat([df_Rho[column], df_Vol_mkt['Return_mkt'], df_Vol_asset[column], df_VaR_asset[column]], 
                            axis=1, join='inner')
    combined_df.columns = ['rho_mi_t', 'sigma_mt1', 'sigma_it1', 'VaR_it1']

    DCoVaR_it = (combined_df['rho_mi_t'] * 
                 (combined_df['sigma_mt1'] / combined_df['sigma_it1']) * 
                  combined_df['VaR_it1']) 
    df_DCoVaR.loc[DCoVaR_it.index, column] = DCoVaR_it

# %%
df_DCoVaR
# Out:
#                  ALL       PNC       MBI       AIG       HIG       UNM  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -0.752967 -1.336299 -0.169444 -1.144442 -1.068968 -0.524996
# 2023-12-26 -0.696108 -1.139095       NaN -1.056703 -0.981135 -0.497315
# 2023-12-27 -0.673273  -1.07243 -0.151752 -1.010979 -0.935181 -0.490745
# 2023-12-28 -0.648929 -1.012274 -0.126774 -0.960253 -0.891353 -0.474387
# 2023-12-29 -0.640615 -0.974135 -0.109103 -0.932192 -0.866109 -0.468784
#
#                  HUM       KEY      CINF        GS       UNH        BK  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  -0.38817 -1.000657 -0.889628 -1.095595 -0.495054 -1.083913
# 2023-12-26 -0.354263 -0.911867  -0.81636 -1.000641 -0.452411 -0.947237
# 2023-12-27 -0.336202 -0.870831 -0.777212 -0.949665 -0.430086 -0.900775
# 2023-12-28 -0.320613 -0.827313 -0.739548 -0.904755 -0.410261 -0.840676
# 2023-12-29 -0.312198 -0.799555 -0.707051 -0.878996 -0.399906 -0.812244
#
#                 NTRS       PGR       AXP      SEIC      FITB      ZION  \
# Date
# 2021-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -1.122931 -0.444308 -1.200825 -1.218018 -1.171508 -1.031806
# 2023-12-26 -0.998484 -0.390431 -1.066742 -1.120318 -1.074097 -0.946711
# 2023-12-27 -0.927443 -0.319051  -0.97826  -1.04774 -1.020407 -0.904909
# 2023-12-28 -0.864267 -0.278897 -0.920024 -1.003792 -0.971948 -0.850442
# 2023-12-29 -0.822024  -0.28023 -0.880408 -0.953995 -0.943911 -0.828054
#
#                  CNA       BEN
# Date
# 2021-01-04       NaN       NaN
# 2021-01-05       NaN       NaN
# 2021-01-06       NaN       NaN
# 2021-01-07       NaN       NaN
# 2021-01-08       NaN       NaN
# ...              ...       ...
# 2023-12-22 -0.508246 -1.149389
# 2023-12-26 -0.505275 -1.044827
# 2023-12-27 -0.500475 -0.964026
# 2023-12-28 -0.475875 -0.930129
# 2023-12-29 -0.515125 -0.862739
#
# [753 rows x 20 columns]
